# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import openweathermapy as ow

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#city = San Diego 
# Print the city count to confirm sufficient count
len(cities)
# print(cities)

cities_df= pd.DataFrame ({
    "City": cities
})
print(cities_df)
# Out:
#                      City
# 0               busselton
# 1                  atuona
# 2                 mataura
# 3         arraial do cabo
# 4          ribeira grande
# 5                  hobart
# 6                   korla
# 7                   kapaa
# 8                  barawe
# 9      sao felix do xingu
# 10                  bluff
# 11             port blair
# 12             georgetown
# 13                 prieta
# 14           punta arenas
# 15           puerto ayora
# 16              mahebourg
# 17               victoria
# 18                ushuaia
# 19                 dingle
# 20               rosarito
# 21                 shingu
# 22                 dikson
# 23               teguldet
# 24                  nalut
# 25                   fare
# 26              paranagua
# 27               katsuura
# 28          berdigestyakh
# 29                 laguna
# ..                    ...
# 579                dryden
# 580                ndjole
# 581            milingimbi
# 582              hendrina
# 583           svetlogorsk
# 584                dabola
# 585               paamiut
# 586         half moon bay
# 587  rocky mountain house
# 588                uvalde
# 589        vestmannaeyjar
# 590               angoche
# 591              sobolevo
# 592       matveyev kurgan
# 593                 ambon
# 594             coldwater
# 595              antalaha
# 596          port-cartier
# 597         san cristobal
# 598               satitoa
# 599              smolenka
# 600            ust-omchug
# 601             taoudenni
# 602                 natal
# 603            san andres
# 604                wronki
# 605             salekhard
# 606                 morwa
# 607              chivasso
# 608                marawi
#
# [609 rows x 1 columns]

# %%
#exporting data to csv file
cities_df.to_csv("Cities_Output.csv")

# %%
cities_list_df = pd.read_csv("Cities_Output.csv")
cities_list_df.head()
# Out:
#    Unnamed: 0             City
# 0           0        busselton
# 1           1           atuona
# 2           2          mataura
# 3           3  arraial do cabo
# 4           4   ribeira grande

# %%
cities_list_df["Lat"] = ""
cities_list_df["Temp"] = ""
cities_list_df["Humidity"] = ""
cities_list_df["Cloudiness"] = ""
cities_list_df["Wind Speed"] = ""
cities_list_df.head()
# Out:
#    Unnamed: 0             City Lat Temp Humidity Cloudiness Wind Speed
# 0           0        busselton
# 1           1           atuona
# 2           2          mataura
# 3           3  arraial do cabo
# 4           4   ribeira grande

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

for city in cities:
    query_url = f"{url}appid={api_key}&q="
    response = requests.get(query_url+city).json()
    pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 79},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1562044966,
#  'id': 2075265,
#  'main': {'humidity': 37,
#           'pressure': 1012,
#           'temp': 291.06,
#           'temp_max': 293.15,
#           'temp_min': 288.71},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'message': 0.0114,
#          'sunrise': 1562023424,
#          'sunset': 1562059258,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 247.187, 'speed': 2.01}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1562044966,
#  'id': 4020109,
#  'main': {'grnd_level': 1013.4,
#           'humidity': 77,
#           'pressure': 1013.33,
#           'sea_level': 1013.33,
#           'temp': 300.148,
#           'temp_max': 300.148,
#           'temp_min': 300.148},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0089,
#          'sunrise': 1561995183,
#          'sunset': 1562036796},
#  'timezone': -34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 102.218, 'speed': 6.89}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1562044967,
#  'id': 6201424,
#  'main': {'humidity': 79,
#           'pressure': 1018,
#           'temp': 285.37,
#           'temp_max': 285.37,
#           'temp_min': 285.37},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0074,
#          'sunrise': 1562012883,
#          'sunset': 1562044111,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 31, 'gust': 3.13, 'speed': 0.89}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1562044967,
#  'id': 3471451,
#  'main': {'grnd_level': 1011,
#           'humidity': 76,
#           'pressure': 1012.74,
#           'sea_level': 1012.74,
#           'temp': 296.348,
#           'temp_max': 296.348,
#           'temp_min': 296.348},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'message': 0.0061,
#          'sunrise': 1562059770,
#          'sunset': 1562098460},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 261.536, 'speed': 3.66}}
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1562044876,
#  'id': 3372707,
#  'main': {'grnd_level': 1027.09,
#           'humidity': 92,
#           'pressure': 1026.99,
#           'sea_level': 1026.99,
#           'temp': 293.448,
#           'temp_max': 293.448,
#           'temp_min': 293.448},
#  'name': 'Ribeira Grande',
#  'rain': {'3h': 0.188},
#  'sys': {'country': 'PT',
#          'message': 0.0057,
#          'sunrise': 1562049270,
#          'sunset': 1562102565},
#  'timezone': 0,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 205.935, 'speed': 5.08}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1562044936,
#  'id': 2163355,
#  'main': {'humidity': 87,
#           'pressure': 1009,
#           'temp': 281.95,
#           'temp_max': 282.15,
#           'temp_min': 281.48},
#  'name': 'Hobart',
#  'rain': {'1h': 0.25},
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0091,
#          'sunrise': 1562017341,
#          'sunset': 1562049989,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 250, 'speed': 3.6}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1562044837,
#  'id': 5848280,
#  'main': {'humidity': 78,
#           'pressure': 1016,
#           'temp': 298.78,
#           'temp_max': 300.15,
#           'temp_min': 297.59},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 7873,
#          'message': 0.0062,
#          'sunrise': 1561996631,
#          'sunset': 1562045088,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 4.6}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -6.64, 'lon': -51.99},
#  'dt': 1562044815,
#  'id': 3388847,
#  'main': {'grnd_level': 981.17,
#           'humidity': 83,
#           'pressure': 1010.86,
#           'sea_level': 1010.86,
#           'temp': 293.348,
#           'temp_max': 293.348,
#           'temp_min': 293.348},
#  'name': 'Sao Felix do Xingu',
#  'sys': {'country': 'BR',
#          'message': 0.0078,
#          'sunrise': 1562060371,
#          'sunset': 1562102645},
#  'timezone': -10800,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 95.727, 'speed': 0.69}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1562044969,
#  'id': 2175403,
#  'main': {'grnd_level': 996.58,
#           'humidity': 45,
#           'pressure': 1016.92,
#           'sea_level': 1016.92,
#           'temp': 295.648,
#           'temp_max': 295.648,
#           'temp_min': 295.648},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0073,
#          'sunrise': 1562013981,
#          'sunset': 1562052514},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120.945, 'speed': 4.69}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 11.67, 'lon': 92.75},
#  'dt': 1562044927,
#  'id': 1259385,
#  'main': {'humidity': 74,
#           'pressure': 1008,
#           'temp': 304.15,
#           'temp_max': 304.15,
#           'temp_min': 304.15},
#  'name': 'Port Blair',
#  'sys': {'country': 'IN',
#          'id': 9215,
#          'message': 0.0064,
#          'sunrise': 1562023732,
#          'sunset': 1562069800,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 5000,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 230, 'speed': 5.1}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1562044970,
#  'id': 3378644,
#  'main': {'humidity': 100,
#           'pressure': 1013,
#           'temp': 296.15,
#           'temp_max': 296.15,
#           'temp_min': 296.15},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'id': 8767,
#          'message': 0.007,
#          'sunrise': 1562060473,
#          'sunset': 1562105505,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 15.58, 'lon': -86.18},
#  'dt': 1562044971,
#  'id': 3603267,
#  'main': {'grnd_level': 960.36,
#           'humidity': 98,
#           'pressure': 1015.98,
#           'sea_level': 1015.98,
#           'temp': 294.048,
#           'temp_max': 294.048,
#           'temp_min': 294.048},
#  'name': 'Prieta',
#  'sys': {'country': 'HN',
#          'message': 0.0058,
#          'sunrise': 1561979837,
#          'sunset': 1562026771},
#  'timezone': -21600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 177.48, 'speed': 0.41}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1562044839,
#  'id': 3874787,
#  'main': {'humidity': 86,
#           'pressure': 1006,
#           'temp': 276.02,
#           'temp_max': 276.15,
#           'temp_min': 275.93},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.0058,
#          'sunrise': 1562072318,
#          'sunset': 1562099780,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 6.7}}
# {'base': 'stations',
#  'clouds': {'all': 72},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1562044971,
#  'id': 3652764,
#  'main': {'humidity': 95,
#           'pressure': 1014,
#           'temp': 294.26,
#           'temp_max': 294.26,
#           'temp_min': 294.26},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 2005652,
#          'message': 0.0063,
#          'sunrise': 1561982564,
#          'sunset': 1562026046,
#          'type': 3},
#  'timezone': -21600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 166.512, 'speed': 3.98}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -20.41, 'lon': 57.7},
#  'dt': 1562044845,
#  'id': 934322,
#  'main': {'humidity': 64,
#           'pressure': 1021,
#           'temp': 296.02,
#           'temp_max': 296.15,
#           'temp_min': 295.93},
#  'name': 'Mahebourg',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'message': 0.0074,
#          'sunrise': 1562035534,
#          'sunset': 1562074824,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09d',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 110, 'speed': 5.7}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1562044972,
#  'id': 1733782,
#  'main': {'humidity': 66,
#           'pressure': 1009,
#           'temp': 306.02,
#           'temp_max': 306.15,
#           'temp_min': 305.93},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 9372,
#          'message': 0.0068,
#          'sunrise': 1562019008,
#          'sunset': 1562063727,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1.5}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1562044972,
#  'id': 3833367,
#  'main': {'humidity': 93,
#           'pressure': 1009,
#           'temp': 275.15,
#           'temp_max': 275.15,
#           'temp_min': 275.15},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0072,
#          'sunrise': 1562072265,
#          'sunset': 1562098586,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 11, 'lon': 122.67},
#  'dt': 1562044972,
#  'id': 1714733,
#  'main': {'grnd_level': 992.05,
#           'humidity': 78,
#           'pressure': 1008.36,
#           'sea_level': 1008.36,
#           'temp': 299.548,
#           'temp_max': 299.548,
#           'temp_min': 299.548},
#  'name': 'Dingle',
#  'sys': {'country': 'PH',
#          'message': 0.0087,
#          'sunrise': 1562016622,
#          'sunset': 1562062546},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 233.269, 'speed': 2.47}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 4.91, 'lon': -75.23},
#  'dt': 1562044973,
#  'id': 3676604,
#  'main': {'humidity': 93,
#           'pressure': 1019,
#           'temp': 292.15,
#           'temp_max': 292.15,
#           'temp_min': 292.15},
#  'name': 'Rosarito',
#  'sys': {'country': 'CO',
#          'id': 8610,
#          'message': 0.0078,
#          'sunrise': 1562064766,
#          'sunset': 1562109406,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.72, 'lon': 135.99},
#  'dt': 1562044973,
#  'id': 1847947,
#  'main': {'humidity': 100,
#           'pressure': 1008,
#           'temp': 295.15,
#           'temp_max': 295.15,
#           'temp_min': 295.15},
#  'name': 'Shingu',
#  'sys': {'country': 'JP',
#          'id': 7959,
#          'message': 0.0074,
#          'sunrise': 1562010548,
#          'sunset': 1562062226,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 5000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 150, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 73.51, 'lon': 80.55},
#  'dt': 1562044974,
#  'id': 1507390,
#  'main': {'grnd_level': 1011.3,
#           'humidity': 69,
#           'pressure': 1012.5,
#           'sea_level': 1012.5,
#           'temp': 281.848,
#           'temp_max': 281.848,
#           'temp_min': 281.848},
#  'name': 'Dikson',
#  'rain': {'3h': 0.688},
#  'sys': {'country': 'RU', 'message': 0.0098, 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 180.7, 'speed': 7.53}}
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': 57.31, 'lon': 88.17},
#  'dt': 1562044974,
#  'id': 1489822,
#  'main': {'grnd_level': 988.13,
#           'humidity': 35,
#           'pressure': 1006.75,
#           'sea_level': 1006.75,
#           'temp': 304.048,
#           'temp_max': 304.048,
#           'temp_min': 304.048},
#  'name': 'Teguldet',
#  'sys': {'country': 'RU',
#          'message': 0.0078,
#          'sunrise': 1562015736,
#          'sunset': 1562079994},
#  'timezone': 25200,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80.133, 'speed': 1.58}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 31.86, 'lon': 10.98},
#  'dt': 1562044975,
#  'id': 2214433,
#  'main': {'grnd_level': 960.44,
#           'humidity': 78,
#           'pressure': 1012.11,
#           'sea_level': 1012.11,
#           'temp': 294.548,
#           'temp_max': 294.548,
#           'temp_min': 294.548},
#  'name': 'Nalut',
#  'sys': {'country': 'LY',
#          'message': 0.0067,
#          'sunrise': 1562040846,
#          'sunset': 1562091940},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 44.823, 'speed': 5.26}}
# {'base': 'stations',
#  'clouds': {'all': 84},
#  'cod': 200,
#  'coord': {'lat': -16.7, 'lon': -151.02},
#  'dt': 1562044975,
#  'id': 4034496,
#  'main': {'grnd_level': 1016.61,
#           'humidity': 79,
#           'pressure': 1016.83,
#           'sea_level': 1016.83,
#           'temp': 298.048,
#           'temp_max': 298.048,
#           'temp_min': 298.048},
#  'name': 'Fare',
#  'rain': {'3h': 0.5},
#  'sys': {'country': 'PF',
#          'message': 0.0065,
#          'sunrise': 1561998804,
#          'sunset': 1562038931},
#  'timezone': -36000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 124.265, 'speed': 12.18}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.93, 'lon': 134.5},
#  'dt': 1562044976,
#  'id': 1865309,
#  'main': {'humidity': 73,
#           'pressure': 1009,
#           'temp': 298.6,
#           'temp_max': 299.26,
#           'temp_min': 298.15},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 8027,
#          'message': 0.0063,
#          'sunrise': 1562010872,
#          'sunset': 1562062617,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 62.1, 'lon': 126.7},
#  'dt': 1562044976,
#  'id': 2026861,
#  'main': {'grnd_level': 976.89,
#           'humidity': 29,
#           'pressure': 1005.23,
#           'sea_level': 1005.23,
#           'temp': 292.248,
#           'temp_max': 292.248,
#           'temp_min': 292.248},
#  'name': 'Berdigestyakh',
#  'sys': {'country': 'RU',
#          'message': 0.0077,
#          'sunrise': 1562003339,
#          'sunset': 1562073895},
#  'timezone': 32400,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 331.064, 'speed': 5.98}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 16.17, 'lon': -88.94},
#  'dt': 1562044976,
#  'id': 3581398,
#  'main': {'humidity': 94,
#           'pressure': 1015,
#           'temp': 299.15,
#           'temp_max': 299.15,
#           'temp_min': 299.15},
#  'name': 'Laguna',
#  'sys': {'country': 'BZ',
#          'id': 7081,
#          'message': 0.0146,
#          'sunrise': 1561980433,
#          'sunset': 1562027500,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 39.325, 'speed': 1.02}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1562044977,
#  'id': 4030556,
#  'main': {'grnd_level': 1021.09,
#           'humidity': 72,
#           'pressure': 1021.41,
#           'sea_level': 1021.41,
#           'temp': 294.148,
#           'temp_max': 294.148,
#           'temp_min': 294.148},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0065,
#          'sunrise': 1561995694,
#          'sunset': 1562034336},
#  'timezone': -32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 131.88, 'speed': 8.04}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1562044977,
#  'id': 546105,
#  'main': {'humidity': 72,
#           'pressure': 998,
#           'temp': 290.62,
#           'temp_max': 291.48,
#           'temp_min': 289.82},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'message': 0.0067,
#          'sunrise': 1562028169,
#          'sunset': 1562095107,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1562044842,
#  'id': 1273574,
#  'main': {'humidity': 83,
#           'pressure': 1011,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'id': 9229,
#          'message': 0.0067,
#          'sunrise': 1562027712,
#          'sunset': 1562074586,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 8000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 6.2}}
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': -16.17, 'lon': -40.69},
#  'dt': 1562044978,
#  'id': 3472520,
#  'main': {'grnd_level': 937.89,
#           'humidity': 97,
#           'pressure': 1016.07,
#           'sea_level': 1016.07,
#           'temp': 286.748,
#           'temp_max': 286.748,
#           'temp_min': 286.748},
#  'name': 'Almenara',
#  'sys': {'country': 'BR',
#          'message': 0.0073,
#          'sunrise': 1562058670,
#          'sunset': 1562098922},
#  'timezone': -10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 303.65, 'speed': 0.4}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 44.08, 'lon': -80.2},
#  'dt': 1562044893,
#  'id': 6145890,
#  'main': {'humidity': 82,
#           'pressure': 1011,
#           'temp': 294.24,
#           'temp_max': 297.15,
#           'temp_min': 290.93},
#  'name': 'Shelburne',
#  'sys': {'country': 'CA',
#          'id': 762,
#          'message': 0.0071,
#          'sunrise': 1562060509,
#          'sunset': 1562116050,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 14484,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 1}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 35.3, 'lon': 37.18},
#  'dt': 1562044979,
#  'id': 172515,
#  'main': {'grnd_level': 963.81,
#           'humidity': 22,
#           'pressure': 1008.05,
#           'sea_level': 1008.05,
#           'temp': 301.148,
#           'temp_max': 301.148,
#           'temp_min': 301.148},
#  'name': 'Abu Samrah',
#  'sys': {'country': 'SY',
#          'message': 0.0076,
#          'sunrise': 1562034014,
#          'sunset': 1562086195},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250.944, 'speed': 1.9}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1562044979,
#  'id': 5855927,
#  'main': {'humidity': 61,
#           'pressure': 1016,
#           'temp': 295.58,
#           'temp_max': 299.15,
#           'temp_min': 293.71},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'message': 0.0067,
#          'sunrise': 1561995899,
#          'sunset': 1562043784,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 31.42, 'lon': 119.48},
#  'dt': 1562044979,
#  'id': 1802788,
#  'main': {'humidity': 52,
#           'pressure': 1008,
#           'temp': 304.15,
#           'temp_max': 304.15,
#           'temp_min': 304.15},
#  'name': 'Liyang',
#  'sys': {'country': 'CN',
#          'id': 9660,
#          'message': 0.0069,
#          'sunrise': 1562014865,
#          'sunset': 1562065835,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 5}}
# {'base': 'stations',
#  'clouds': {'all': 26},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1562044980,
#  'id': 1015776,
#  'main': {'humidity': 55,
#           'pressure': 1017,
#           'temp': 289.22,
#           'temp_max': 289.26,
#           'temp_min': 289.15},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'message': 0.0081,
#          'sunrise': 1562046433,
#          'sunset': 1562082005,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 8.7}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 22.75, 'lon': 108.49},
#  'dt': 1562044980,
#  'id': 1798480,
#  'main': {'humidity': 66,
#           'pressure': 1002,
#           'temp': 306.15,
#           'temp_max': 306.15,
#           'temp_min': 306.15},
#  'name': 'Pumiao',
#  'sys': {'country': 'CN',
#          'id': 9628,
#          'message': 0.0066,
#          'sunrise': 1562018679,
#          'sunset': 1562067297,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 3}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1562044980,
#  'id': 4407665,
#  'main': {'humidity': 78,
#           'pressure': 1015,
#           'temp': 298.27,
#           'temp_max': 300.93,
#           'temp_min': 295.93},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 5924,
#          'message': 0.0064,
#          'sunrise': 1562064862,
#          'sunset': 1562118686,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1562044981,
#  'id': 3366880,
#  'main': {'humidity': 65,
#           'pressure': 1013,
#           'temp': 287.13,
#           'temp_max': 289.26,
#           'temp_min': 285.37},
#  'name': 'Hermanus',
#  'rain': {'3h': 0.688},
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'message': 0.0081,
#          'sunrise': 1562046608,
#          'sunset': 1562082213,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 322, 'gust': 10.73, 'speed': 3.13}}
# {'base': 'stations',
#  'clouds': {'all': 84},
#  'cod': 200,
#  'coord': {'lat': -19.06, 'lon': -169.92},
#  'dt': 1562044804,
#  'id': 4036284,
#  'main': {'humidity': 78,
#           'pressure': 1016,
#           'temp': 297.15,
#           'temp_max': 297.15,
#           'temp_min': 297.15},
#  'name': 'Alofi',
#  'rain': {'3h': 0.313},
#  'sys': {'country': 'NU',
#          'id': 7306,
#          'message': 0.0082,
#          'sunrise': 1562003606,
#          'sunset': 1562043202,
#          'type': 1},
#  'timezone': -39600,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 100, 'speed': 7.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 64.92, 'lon': 77.78},
#  'dt': 1562044981,
#  'id': 1490085,
#  'main': {'humidity': 32,
#           'pressure': 1017,
#           'temp': 303.15,
#           'temp_max': 303.15,
#           'temp_min': 303.15},
#  'name': 'Tarko-Sale',
#  'sys': {'country': 'RU',
#          'id': 265489,
#          'message': 0.0067,
#          'sunrise': 1562011640,
#          'sunset': 1562089079,
#          'type': 3},
#  'timezone': 18000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 136.815, 'speed': 4.26}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1562044982,
#  'id': 964432,
#  'main': {'humidity': 61,
#           'pressure': 1018,
#           'temp': 285.93,
#           'temp_max': 285.93,
#           'temp_min': 285.93},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'message': 0.0072,
#          'sunrise': 1562044647,
#          'sunset': 1562080502,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 324, 'gust': 8.05, 'speed': 4.02}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1562044693,
#  'id': 3369157,
#  'main': {'humidity': 76,
#           'pressure': 1021,
#           'temp': 287.15,
#           'temp_max': 287.59,
#           'temp_min': 287.04},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'message': 0.0071,
#          'sunrise': 1562046730,
#          'sunset': 1562082485,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 7.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.63, 'lon': 48.68},
#  'dt': 1562044982,
#  'id': 586001,
#  'main': {'grnd_level': 968.36,
#           'humidity': 36,
#           'pressure': 1019.34,
#           'sea_level': 1019.34,
#           'temp': 296.948,
#           'temp_max': 296.948,
#           'temp_min': 296.948},
#  'name': 'Khudat',
#  'sys': {'country': 'AZ',
#          'message': 0.0071,
#          'sunrise': 1562030092,
#          'sunset': 1562084597},
#  'timezone': 14400,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 133.356, 'speed': 4.66}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1562044840,
#  'id': 6165406,
#  'main': {'humidity': 87,
#           'pressure': 1005,
#           'temp': 283.15,
#           'temp_max': 283.15,
#           'temp_min': 283.15},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'message': 0.0086,
#          'sunrise': 1562061146,
#          'sunset': 1562123890,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 9656,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1562044983,
#  'id': 2069194,
#  'main': {'grnd_level': 985.96,
#           'humidity': 61,
#           'pressure': 1022.58,
#           'sea_level': 1022.58,
#           'temp': 286.948,
#           'temp_max': 286.948,
#           'temp_min': 286.948},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0062,
#          'sunrise': 1562017780,
#          'sunset': 1562053741},
#  'timezone': 34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 232.572, 'speed': 2.06}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -35.3, 'lon': 148.22},
#  'dt': 1562044983,
#  'id': 2145875,
#  'main': {'grnd_level': 944.31,
#           'humidity': 60,
#           'pressure': 1021.56,
#           'sea_level': 1021.56,
#           'temp': 282.348,
#           'temp_max': 282.348,
#           'temp_min': 282.348},
#  'name': 'Tumut',
#  'sys': {'country': 'AU',
#          'message': 0.0093,
#          'sunrise': 1562015790,
#          'sunset': 1562051113},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 254.518, 'speed': 2.06}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.13, 'lon': 150.74},
#  'dt': 1562044984,
#  'id': 2142316,
#  'main': {'humidity': 27,
#           'pressure': 1016,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'Yeppoon',
#  'sys': {'country': 'AU',
#          'id': 9499,
#          'message': 0.0064,
#          'sunrise': 1562013526,
#          'sunset': 1562052168,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -42.78, 'lon': 147.06},
#  'dt': 1562044839,
#  'id': 2155415,
#  'main': {'humidity': 87,
#           'pressure': 1009,
#           'temp': 281.95,
#           'temp_max': 282.15,
#           'temp_min': 281.48},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0074,
#          'sunrise': 1562017386,
#          'sunset': 1562050074,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 250, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 9.16, 'lon': 39.02},
#  'dt': 1562044984,
#  'id': 328880,
#  'main': {'humidity': 77,
#           'pressure': 1027,
#           'temp': 289.15,
#           'temp_max': 289.15,
#           'temp_min': 289.15},
#  'name': 'Sendafa',
#  'sys': {'country': 'ET',
#          'id': 2453,
#          'message': 0.0068,
#          'sunrise': 1562036898,
#          'sunset': 1562082428,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -21.42, 'lon': 25.59},
#  'dt': 1562044985,
#  'id': 933535,
#  'main': {'grnd_level': 907.54,
#           'humidity': 41,
#           'pressure': 1025.72,
#           'sea_level': 1025.72,
#           'temp': 280.748,
#           'temp_max': 280.748,
#           'temp_min': 280.748},
#  'name': 'Letlhakane',
#  'sys': {'country': 'BW',
#          'message': 0.0058,
#          'sunrise': 1562043359,
#          'sunset': 1562082414},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 151.403, 'speed': 5.26}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 27.8, 'lon': 66.62},
#  'dt': 1562044985,
#  'id': 7082481,
#  'main': {'grnd_level': 841.77,
#           'humidity': 26,
#           'pressure': 1000.91,
#           'sea_level': 1000.91,
#           'temp': 306.548,
#           'temp_max': 306.548,
#           'temp_min': 306.548},
#  'name': 'Khuzdar',
#  'sys': {'country': 'PK',
#          'message': 0.0061,
#          'sunrise': 1562028072,
#          'sunset': 1562078005},
#  'timezone': 18000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 102.915, 'speed': 3.62}}
# {'base': 'stations',
#  'clouds': {'all': 72},
#  'cod': 200,
#  'coord': {'lat': 55.53, 'lon': 70.34},
#  'dt': 1562044985,
#  'id': 1491719,
#  'main': {'grnd_level': 993.25,
#           'humidity': 61,
#           'pressure': 1008.6,
#           'sea_level': 1008.6,
#           'temp': 294.148,
#           'temp_max': 294.148,
#           'temp_min': 294.148},
#  'name': 'Sladkovo',
#  'sys': {'country': 'RU',
#          'message': 0.0071,
#          'sunrise': 1562020846,
#          'sunset': 1562083444},
#  'timezone': 18000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 123.197, 'speed': 8.98}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 21.44, 'lon': -157.84},
#  'dt': 1562044986,
#  'id': 5856516,
#  'main': {'humidity': 83,
#           'pressure': 1014,
#           'temp': 299.52,
#           'temp_max': 301.15,
#           'temp_min': 297.04},
#  'name': 'Ahuimanu',
#  'sys': {'country': 'US',
#          'id': 7877,
#          'message': 0.007,
#          'sunrise': 1561996354,
#          'sunset': 1562044655,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 70, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1562044986,
#  'id': 6185377,
#  'main': {'humidity': 87,
#           'pressure': 1006,
#           'temp': 284.15,
#           'temp_max': 284.15,
#           'temp_min': 284.15},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'message': 0.0093,
#          'sunrise': 1561974452,
#          'sunset': 1562045694,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 340, 'gust': 11.3, 'speed': 7.2}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.72, 'lon': 135.86},
#  'dt': 1562044912,
#  'id': 2063036,
#  'main': {'grnd_level': 1022.81,
#           'humidity': 70,
#           'pressure': 1022.69,
#           'sea_level': 1022.69,
#           'temp': 288.148,
#           'temp_max': 288.148,
#           'temp_min': 288.148},
#  'name': 'Port Lincoln',
#  'sys': {'country': 'AU',
#          'message': 0.0105,
#          'sunrise': 1562018666,
#          'sunset': 1562054170},
#  'timezone': 34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 202.506, 'speed': 2.75}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 50.09, 'lon': -96.94},
#  'dt': 1562044987,
#  'id': 6144054,
#  'main': {'humidity': 52,
#           'pressure': 1009,
#           'temp': 291.93,
#           'temp_max': 294.15,
#           'temp_min': 289.82},
#  'name': 'Lockport',
#  'sys': {'country': 'CA',
#          'id': 971,
#          'message': 0.0068,
#          'sunrise': 1562062968,
#          'sunset': 1562121627,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 36.62, 'lon': -121.92},
#  'dt': 1562044987,
#  'id': 5380437,
#  'main': {'humidity': 82,
#           'pressure': 1018,
#           'temp': 287.66,
#           'temp_max': 289.26,
#           'temp_min': 285.93},
#  'name': 'Pacific Grove',
#  'sys': {'country': 'US',
#          'id': 4980,
#          'message': 0.0102,
#          'sunrise': 1561985560,
#          'sunset': 1562038205,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 25.29, 'lon': 51.53},
#  'dt': 1562044702,
#  'id': 290030,
#  'main': {'humidity': 31,
#           'pressure': 997,
#           'temp': 311.48,
#           'temp_max': 312.15,
#           'temp_min': 311.15},
#  'name': 'Doha',
#  'sys': {'country': 'QA',
#          'id': 7614,
#          'message': 0.007,
#          'sunrise': 1562032029,
#          'sunset': 1562081291,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 310, 'speed': 6.7}}
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1562044988,
#  'id': 2022572,
#  'main': {'grnd_level': 1018.36,
#           'humidity': 32,
#           'pressure': 1021.18,
#           'sea_level': 1021.18,
#           'temp': 288.748,
#           'temp_max': 288.748,
#           'temp_min': 288.748},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'message': 0.0056, 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 9.414, 'speed': 2.56}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 27.97, 'lon': -114.04},
#  'dt': 1562044988,
#  'id': 4021858,
#  'main': {'grnd_level': 1012.77,
#           'humidity': 76,
#           'pressure': 1012.5,
#           'sea_level': 1012.5,
#           'temp': 293.348,
#           'temp_max': 293.348,
#           'temp_min': 293.348},
#  'name': 'Guerrero Negro',
#  'sys': {'country': 'MX',
#          'message': 0.0056,
#          'sunrise': 1561984996,
#          'sunset': 1562034986},
#  'timezone': -21600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 325.265, 'speed': 7.97}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 33.82, 'lon': 71.89},
#  'dt': 1562044988,
#  'id': 1181327,
#  'main': {'humidity': 36,
#           'pressure': 1001,
#           'temp': 307.15,
#           'temp_max': 307.15,
#           'temp_min': 307.15},
#  'name': 'Cherat',
#  'sys': {'country': 'PK',
#          'id': 7590,
#          'message': 0.009,
#          'sunrise': 1562025921,
#          'sunset': 1562077625,
#          'type': 1},
#  'timezone': 18000,
#  'visibility': 6000,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 360, 'speed': 5.1}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 26.05, 'lon': -97.95},
#  'dt': 1562044989,
#  'id': 3520271,
#  'main': {'humidity': 83,
#           'pressure': 1015,
#           'temp': 300.18,
#           'temp_max': 301.15,
#           'temp_min': 299.15},
#  'name': 'Nuevo Progreso',
#  'sys': {'country': 'US',
#          'id': 6100,
#          'message': 0.0083,
#          'sunrise': 1562067813,
#          'sunset': 1562117266,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1562044877,
#  'id': 3863379,
#  'main': {'grnd_level': 963.93,
#           'humidity': 66,
#           'pressure': 999.06,
#           'sea_level': 999.06,
#           'temp': 274.248,
#           'temp_max': 274.248,
#           'temp_min': 274.248},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.007,
#          'sunrise': 1562069662,
#          'sunset': 1562100810},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 226.435, 'speed': 6.86}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 5.11, 'lon': -1.24},
#  'dt': 1562044989,
#  'id': 2302357,
#  'main': {'grnd_level': 1011,
#           'humidity': 90,
#           'pressure': 1012.22,
#           'sea_level': 1012.22,
#           'temp': 297.948,
#           'temp_max': 297.948,
#           'temp_min': 297.948},
#  'name': 'Cape Coast',
#  'sys': {'country': 'GH',
#          'message': 0.0055,
#          'sunrise': 1562046985,
#          'sunset': 1562091668},
#  'timezone': 0,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 214.512, 'speed': 2.47}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 9.91, 'lon': -67.35},
#  'dt': 1562044990,
#  'id': 3628053,
#  'main': {'grnd_level': 935.59,
#           'humidity': 95,
#           'pressure': 1013.45,
#           'sea_level': 1013.45,
#           'temp': 292.948,
#           'temp_max': 292.948,
#           'temp_min': 292.948},
#  'name': 'San Juan de los Morros',
#  'sys': {'country': 'VE',
#          'message': 0.0093,
#          'sunrise': 1562062351,
#          'sunset': 1562108038},
#  'timezone': -14400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 79.844, 'speed': 0.52}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 64.17, 'lon': -51.74},
#  'dt': 1562044990,
#  'id': 3421319,
#  'main': {'humidity': 93,
#           'pressure': 1013,
#           'temp': 276.15,
#           'temp_max': 276.15,
#           'temp_min': 276.15},
#  'name': 'Nuuk',
#  'sys': {'country': 'GL',
#          'id': 86,
#          'message': 0.0087,
#          'sunrise': 1562043956,
#          'sunset': 1562118940,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 360, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': 57.8, 'lon': 158.67},
#  'dt': 1562044991,
#  'id': 2120612,
#  'main': {'grnd_level': 1004.1,
#           'humidity': 75,
#           'pressure': 1010.64,
#           'sea_level': 1010.64,
#           'temp': 285.548,
#           'temp_max': 285.548,
#           'temp_min': 285.548},
#  'name': 'Tigil',
#  'sys': {'country': 'RU',
#          'message': 0.0055,
#          'sunrise': 1561998554,
#          'sunset': 1562063332},
#  'timezone': 43200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 309.968, 'speed': 3.88}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 10.31, 'lon': 9.75},
#  'dt': 1562044991,
#  'id': 2347470,
#  'main': {'grnd_level': 942.89,
#           'humidity': 83,
#           'pressure': 1010.46,
#           'sea_level': 1010.46,
#           'temp': 296.148,
#           'temp_max': 296.148,
#           'temp_min': 296.148},
#  'name': 'Miri',
#  'sys': {'country': 'NG',
#          'message': 0.007,
#          'sunrise': 1562043802,
#          'sunset': 1562089575},
#  'timezone': 3600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 215.157, 'speed': 2.47}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.72, 'lon': -46.03},
#  'dt': 1562044992,
#  'id': 3420846,
#  'main': {'humidity': 61,
#           'pressure': 1010,
#           'temp': 281.15,
#           'temp_max': 281.15,
#           'temp_min': 281.15},
#  'name': 'Qaqortoq',
#  'sys': {'country': 'GL',
#          'id': 47,
#          'message': 0.0057,
#          'sunrise': 1562045930,
#          'sunset': 1562114225,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 70, 'speed': 6.2}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1562044789,
#  'id': 3985710,
#  'main': {'humidity': 78,
#           'pressure': 1013,
#           'temp': 296.7,
#           'temp_max': 297.59,
#           'temp_min': 295.37},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 7165,
#          'message': 0.0075,
#          'sunrise': 1561984669,
#          'sunset': 1562033330,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 120, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 39.65, 'lon': -104.99},
#  'dt': 1562044779,
#  'id': 5421250,
# ...
#           'sea_level': 1012.73,
#           'temp': 293.248,
#           'temp_max': 293.248,
#           'temp_min': 293.248},
#  'name': 'Dabola',
#  'rain': {'3h': 0.125},
#  'sys': {'country': 'GN',
#          'message': 0.0066,
#          'sunrise': 1562048763,
#          'sunset': 1562094628},
#  'timezone': 0,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 228.751, 'speed': 0.68}}
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 61.99, 'lon': -49.67},
#  'dt': 1562045180,
#  'id': 3421193,
#  'main': {'grnd_level': 1012.6,
#           'humidity': 91,
#           'pressure': 1011.85,
#           'sea_level': 1011.85,
#           'temp': 276.748,
#           'temp_max': 276.748,
#           'temp_min': 276.748},
#  'name': 'Paamiut',
#  'sys': {'country': 'GL',
#          'message': 0.0083,
#          'sunrise': 1562045804,
#          'sunset': 1562116099},
#  'timezone': -7200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 312.633, 'speed': 6.01}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 37.46, 'lon': -122.43},
#  'dt': 1562045181,
#  'id': 5354943,
#  'main': {'humidity': 87,
#           'pressure': 1018,
#           'temp': 287.47,
#           'temp_max': 290.15,
#           'temp_min': 285.37},
#  'name': 'Half Moon Bay',
#  'sys': {'country': 'US',
#          'id': 4322,
#          'message': 0.0116,
#          'sunrise': 1561985536,
#          'sunset': 1562038474,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 12874,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 52.38, 'lon': -114.92},
#  'dt': 1562045181,
#  'id': 6126749,
#  'main': {'grnd_level': 903.88,
#           'humidity': 93,
#           'pressure': 1018.65,
#           'sea_level': 1018.65,
#           'temp': 279.548,
#           'temp_max': 279.548,
#           'temp_min': 279.548},
#  'name': 'Rocky Mountain House',
#  'rain': {'3h': 0.188},
#  'sys': {'country': 'CA',
#          'message': 0.0069,
#          'sunrise': 1561980104,
#          'sunset': 1562040301},
#  'timezone': -21600,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 279.13, 'speed': 3.28}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 29.21, 'lon': -99.79},
#  'dt': 1562045103,
#  'id': 4738721,
#  'main': {'humidity': 74,
#           'pressure': 1016,
#           'temp': 298.6,
#           'temp_max': 299.82,
#           'temp_min': 297.59},
#  'name': 'Uvalde',
#  'sys': {'country': 'US',
#          'id': 6147,
#          'message': 0.0103,
#          'sunrise': 1562067824,
#          'sunset': 1562118139,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 5.1}}
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': 63.44, 'lon': -20.27},
#  'dt': 1562045120,
#  'id': 3412093,
#  'main': {'grnd_level': 1020.47,
#           'humidity': 64,
#           'pressure': 1021.06,
#           'sea_level': 1021.06,
#           'temp': 282.148,
#           'temp_max': 282.148,
#           'temp_min': 282.148},
#  'name': 'Vestmannaeyjar',
#  'sys': {'country': 'IS',
#          'message': 0.0058,
#          'sunrise': 1562037307,
#          'sunset': 1562110482},
#  'timezone': 0,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 326.548, 'speed': 4.41}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -16.23, 'lon': 39.91},
#  'dt': 1562045182,
#  'id': 1052944,
#  'main': {'grnd_level': 1013,
#           'humidity': 81,
#           'pressure': 1017.72,
#           'sea_level': 1017.72,
#           'temp': 297.448,
#           'temp_max': 297.448,
#           'temp_min': 297.448},
#  'name': 'Angoche',
#  'sys': {'country': 'MZ',
#          'message': 0.0079,
#          'sunrise': 1562039331,
#          'sunset': 1562079567},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 302.938, 'speed': 1.29}}
# {'base': 'stations',
#  'clouds': {'all': 69},
#  'cod': 200,
#  'coord': {'lat': 54.43, 'lon': 31.9},
#  'dt': 1562045183,
#  'id': 525426,
#  'main': {'grnd_level': 982.71,
#           'humidity': 77,
#           'pressure': 1007.48,
#           'sea_level': 1007.48,
#           'temp': 289.648,
#           'temp_max': 289.648,
#           'temp_min': 289.648},
#  'name': 'Sobolevo',
#  'sys': {'country': 'RU',
#          'message': 0.0061,
#          'sunrise': 1562030532,
#          'sunset': 1562092212},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 273.202, 'speed': 5.21}}
# {'base': 'stations',
#  'clouds': {'all': 4},
#  'cod': 200,
#  'coord': {'lat': 47.57, 'lon': 38.86},
#  'dt': 1562045183,
#  'id': 528495,
#  'main': {'grnd_level': 1002.21,
#           'humidity': 54,
#           'pressure': 1012.21,
#           'sea_level': 1012.21,
#           'temp': 299.148,
#           'temp_max': 299.148,
#           'temp_min': 299.148},
#  'name': 'Matveyev Kurgan',
#  'sys': {'country': 'RU',
#          'message': 0.0061,
#          'sunrise': 1562031072,
#          'sunset': 1562088330},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 256.543, 'speed': 6.14}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 47.55, 'lon': -2.56},
#  'dt': 1562045183,
#  'id': 3037899,
#  'main': {'humidity': 100,
#           'pressure': 1022,
#           'temp': 285.07,
#           'temp_max': 287.04,
#           'temp_min': 283.71},
#  'name': 'Ambon',
#  'sys': {'country': 'FR',
#          'id': 6576,
#          'message': 0.0077,
#          'sunrise': 1562041022,
#          'sunset': 1562098264,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.94, 'lon': -85},
#  'dt': 1562045184,
#  'id': 4989266,
#  'main': {'humidity': 94,
#           'pressure': 1014,
#           'temp': 295.56,
#           'temp_max': 297.15,
#           'temp_min': 294.15},
#  'name': 'Coldwater',
#  'sys': {'country': 'US',
#          'id': 4625,
#          'message': 0.0074,
#          'sunrise': 1562062123,
#          'sunset': 1562116740,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 315.363, 'speed': 2.12}}
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': -14.9, 'lon': 50.28},
#  'dt': 1562045184,
#  'id': 1071296,
#  'main': {'grnd_level': 969.57,
#           'humidity': 68,
#           'pressure': 1018.04,
#           'sea_level': 1018.04,
#           'temp': 293.848,
#           'temp_max': 293.848,
#           'temp_min': 293.848},
#  'name': 'Antalaha',
#  'sys': {'country': 'MG',
#          'message': 0.0062,
#          'sunrise': 1562036696,
#          'sunset': 1562077224},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 209.777, 'speed': 1.8}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 50.03, 'lon': -66.88},
#  'dt': 1562045185,
#  'id': 6111696,
#  'main': {'humidity': 82,
#           'pressure': 1007,
#           'temp': 286.03,
#           'temp_max': 286.15,
#           'temp_min': 285.93},
#  'name': 'Port-Cartier',
#  'sys': {'country': 'CA',
#          'id': 1013,
#          'message': 0.0061,
#          'sunrise': 1562055768,
#          'sunset': 1562114396,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 14.68, 'lon': -86.92},
#  'dt': 1562045185,
#  'id': 3609418,
#  'main': {'grnd_level': 913.27,
#           'humidity': 97,
#           'pressure': 1015.94,
#           'sea_level': 1015.94,
#           'temp': 291.948,
#           'temp_max': 291.948,
#           'temp_min': 291.948},
#  'name': 'San Cristobal',
#  'rain': {'3h': 0.188},
#  'sys': {'country': 'HN',
#          'message': 0.0067,
#          'sunrise': 1561980115,
#          'sunset': 1562026848},
#  'timezone': -21600,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 94.737, 'speed': 1.8}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 54.15, 'lon': 22.76},
#  'dt': 1562045185,
#  'id': 757718,
#  'main': {'grnd_level': 996.02,
#           'humidity': 82,
#           'pressure': 1009.49,
#           'sea_level': 1009.49,
#           'temp': 289.148,
#           'temp_max': 289.148,
#           'temp_min': 289.148},
#  'name': 'Smolenka',
#  'sys': {'country': 'PL',
#          'message': 0.0059,
#          'sunrise': 1562032837,
#          'sunset': 1562094294},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 263.641, 'speed': 6.49}}
# {'base': 'stations',
#  'clouds': {'all': 65},
#  'cod': 200,
#  'coord': {'lat': 61.13, 'lon': 149.63},
#  'dt': 1562045186,
#  'id': 2120047,
#  'main': {'grnd_level': 909.29,
#           'humidity': 48,
#           'pressure': 1002.58,
#           'sea_level': 1002.58,
#           'temp': 291.948,
#           'temp_max': 291.948,
#           'temp_min': 291.948},
#  'name': 'Ust-Omchug',
#  'rain': {'3h': 0.313},
#  'sys': {'country': 'RU',
#          'message': 0.0071,
#          'sunrise': 1561998628,
#          'sunset': 1562067598},
#  'timezone': 39600,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 206.904, 'speed': 4.16}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.68, 'lon': -3.98},
#  'dt': 1562044904,
#  'id': 2450173,
#  'main': {'grnd_level': 985.96,
#           'humidity': 12,
#           'pressure': 1007.16,
#           'sea_level': 1007.16,
#           'temp': 305.648,
#           'temp_max': 305.648,
#           'temp_min': 305.648},
#  'name': 'Taoudenni',
#  'sys': {'country': 'ML',
#          'message': 0.0054,
#          'sunrise': 1562045686,
#          'sunset': 1562094282},
#  'timezone': 0,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 25.492, 'speed': 1.55}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -5.81, 'lon': -35.21},
#  'dt': 1562045187,
#  'id': 3394023,
#  'main': {'humidity': 94,
#           'pressure': 1013,
#           'temp': 295.15,
#           'temp_max': 295.15,
#           'temp_min': 295.15},
#  'name': 'Natal',
#  'sys': {'country': 'BR',
#          'id': 8417,
#          'message': 0.007,
#          'sunrise': 1562056258,
#          'sunset': 1562098703,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 13.32, 'lon': 122.68},
#  'dt': 1562045187,
#  'id': 1690438,
#  'main': {'grnd_level': 997.77,
#           'humidity': 71,
#           'pressure': 1008.32,
#           'sea_level': 1008.32,
#           'temp': 300.648,
#           'temp_max': 300.648,
#           'temp_min': 300.648},
#  'name': 'San Andres',
#  'sys': {'country': 'PH',
#          'message': 0.0074,
#          'sunrise': 1562016368,
#          'sunset': 1562062796},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 195.313, 'speed': 3.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 52.71, 'lon': 16.37},
#  'dt': 1562045188,
#  'id': 3081350,
#  'main': {'humidity': 59,
#           'pressure': 1016,
#           'temp': 291.12,
#           'temp_max': 291.48,
#           'temp_min': 290.15},
#  'name': 'Wronki',
#  'sys': {'country': 'PL',
#          'id': 1710,
#          'message': 0.0074,
#          'sunrise': 1562034906,
#          'sunset': 1562095293,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 65},
#  'cod': 200,
#  'coord': {'lat': 66.54, 'lon': 66.62},
#  'dt': 1562045188,
#  'id': 1493197,
#  'main': {'grnd_level': 1008.52,
#           'humidity': 36,
#           'pressure': 1010.31,
#           'sea_level': 1010.31,
#           'temp': 300.648,
#           'temp_max': 300.648,
#           'temp_min': 300.648},
#  'name': 'Salekhard',
#  'sys': {'country': 'RU', 'message': 0.0067, 'sunrise': 0, 'sunset': 0},
#  'timezone': 18000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 192.075, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24.44, 'lon': 26.07},
#  'dt': 1562045189,
#  'id': 933340,
#  'main': {'humidity': 64,
#           'pressure': 1026,
#           'temp': 277.15,
#           'temp_max': 277.15,
#           'temp_min': 277.15},
#  'name': 'Morwa',
#  'sys': {'country': 'BW',
#          'id': 2012,
#          'message': 0.0065,
#          'sunrise': 1562043607,
#          'sunset': 1562081936,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 1.5}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 45.19, 'lon': 7.89},
#  'dt': 1562045189,
#  'id': 6538052,
#  'main': {'humidity': 68,
#           'pressure': 1017,
#           'temp': 293.52,
#           'temp_max': 297.04,
#           'temp_min': 289.82},
#  'name': 'Chivasso',
#  'sys': {'country': 'IT',
#          'id': 6736,
#          'message': 0.0076,
#          'sunrise': 1562039103,
#          'sunset': 1562095167,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 8, 'lon': 124.29},
#  'dt': 1562044934,
#  'id': 1701054,
#  'main': {'humidity': 74,
#           'pressure': 1010,
#           'temp': 302.59,
#           'temp_max': 302.59,
#           'temp_min': 302.59},
#  'name': 'Marawi',
#  'rain': {'3h': 1.75},
#  'sys': {'country': 'PH',
#          'id': 2007154,
#          'message': 0.005,
#          'sunrise': 1562016552,
#          'sunset': 1562061839,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 13, 'gust': 5.36, 'speed': 2.24}}

# %%
search_params={"key": api_key,
#               "keyword": City
              }

for index, row in cities_list_df.iterrows():
    base_url="http://api.openweathermap.org/data/2.5/weather?"
    search_params["name"]= row['City']
    
    print(f"Retrieving results for index {index}: [row['City']")
    response=requests.get(base_url, params=search_params).json()
    
#     name=response['name']
    try:
        cities_list_df.loc[index,"Lat"]= response['coord']['lat']
        cities_list_df.loc[index, "Temp"] = response['main']['temp'.F]
        cities_list_df.loc[index, "Humidity"] = response['main']['humidity']
        cities_list_df.loc[index, "Cloudiness"] = response["weather"][0]["description"]
        cities_list_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping")
        
cities_list_df.head()
# Out:
# Retrieving results for index 0: [row['City']
# Missing field/result... skipping
# Retrieving results for index 1: [row['City']
# Missing field/result... skipping
# Retrieving results for index 2: [row['City']
# Missing field/result... skipping
# Retrieving results for index 3: [row['City']
# Missing field/result... skipping
# Retrieving results for index 4: [row['City']
# Missing field/result... skipping
# Retrieving results for index 5: [row['City']
# Missing field/result... skipping
# Retrieving results for index 6: [row['City']
# Missing field/result... skipping
# Retrieving results for index 7: [row['City']
# Missing field/result... skipping
# Retrieving results for index 8: [row['City']
# Missing field/result... skipping
# Retrieving results for index 9: [row['City']
# Missing field/result... skipping
# Retrieving results for index 10: [row['City']
# Missing field/result... skipping
# Retrieving results for index 11: [row['City']
# Missing field/result... skipping
# Retrieving results for index 12: [row['City']
# Missing field/result... skipping
# Retrieving results for index 13: [row['City']
# Missing field/result... skipping
# Retrieving results for index 14: [row['City']
# Missing field/result... skipping
# Retrieving results for index 15: [row['City']
# Missing field/result... skipping
# Retrieving results for index 16: [row['City']
# Missing field/result... skipping
# Retrieving results for index 17: [row['City']
# Missing field/result... skipping
# Retrieving results for index 18: [row['City']
# Missing field/result... skipping
# Retrieving results for index 19: [row['City']
# Missing field/result... skipping
# Retrieving results for index 20: [row['City']
# Missing field/result... skipping
# Retrieving results for index 21: [row['City']
# Missing field/result... skipping
# Retrieving results for index 22: [row['City']
# Missing field/result... skipping
# Retrieving results for index 23: [row['City']
# Missing field/result... skipping
# Retrieving results for index 24: [row['City']
# Missing field/result... skipping
# Retrieving results for index 25: [row['City']
# Missing field/result... skipping
# Retrieving results for index 26: [row['City']
# Missing field/result... skipping
# Retrieving results for index 27: [row['City']
# Missing field/result... skipping
# Retrieving results for index 28: [row['City']
# Missing field/result... skipping
# Retrieving results for index 29: [row['City']
# Missing field/result... skipping
# Retrieving results for index 30: [row['City']
# Missing field/result... skipping
# Retrieving results for index 31: [row['City']
# Missing field/result... skipping
# Retrieving results for index 32: [row['City']
# Missing field/result... skipping
# Retrieving results for index 33: [row['City']
# Missing field/result... skipping
# Retrieving results for index 34: [row['City']
# Missing field/result... skipping
# Retrieving results for index 35: [row['City']
# Missing field/result... skipping
# Retrieving results for index 36: [row['City']
# Missing field/result... skipping
# Retrieving results for index 37: [row['City']
# Missing field/result... skipping
# Retrieving results for index 38: [row['City']
# Missing field/result... skipping
# Retrieving results for index 39: [row['City']
# Missing field/result... skipping
# Retrieving results for index 40: [row['City']
# Missing field/result... skipping
# Retrieving results for index 41: [row['City']
# Missing field/result... skipping
# Retrieving results for index 42: [row['City']
# Missing field/result... skipping
# Retrieving results for index 43: [row['City']
# Missing field/result... skipping
# Retrieving results for index 44: [row['City']
# Missing field/result... skipping
# Retrieving results for index 45: [row['City']
# Missing field/result... skipping
# Retrieving results for index 46: [row['City']
# Missing field/result... skipping
# Retrieving results for index 47: [row['City']
# Missing field/result... skipping
# Retrieving results for index 48: [row['City']
# Missing field/result... skipping
# Retrieving results for index 49: [row['City']
# Missing field/result... skipping
# Retrieving results for index 50: [row['City']
# Missing field/result... skipping
# Retrieving results for index 51: [row['City']
# Missing field/result... skipping
# Retrieving results for index 52: [row['City']
# Missing field/result... skipping
# Retrieving results for index 53: [row['City']
# Missing field/result... skipping
# Retrieving results for index 54: [row['City']
# Missing field/result... skipping
# Retrieving results for index 55: [row['City']
# Missing field/result... skipping
# Retrieving results for index 56: [row['City']
# Missing field/result... skipping
# Retrieving results for index 57: [row['City']
# Missing field/result... skipping
# Retrieving results for index 58: [row['City']
# Missing field/result... skipping
# Retrieving results for index 59: [row['City']
# Missing field/result... skipping
# Retrieving results for index 60: [row['City']
# Missing field/result... skipping
# Retrieving results for index 61: [row['City']
# Missing field/result... skipping
# Retrieving results for index 62: [row['City']
# Missing field/result... skipping
# Retrieving results for index 63: [row['City']
# Missing field/result... skipping
# Retrieving results for index 64: [row['City']
# Missing field/result... skipping
# Retrieving results for index 65: [row['City']
# Missing field/result... skipping
# Retrieving results for index 66: [row['City']
# Missing field/result... skipping
# Retrieving results for index 67: [row['City']
# Missing field/result... skipping
# Retrieving results for index 68: [row['City']
# Missing field/result... skipping
# Retrieving results for index 69: [row['City']
# Missing field/result... skipping
# Retrieving results for index 70: [row['City']
# Missing field/result... skipping
# Retrieving results for index 71: [row['City']
# Missing field/result... skipping
# Retrieving results for index 72: [row['City']
# Missing field/result... skipping
# Retrieving results for index 73: [row['City']
# Missing field/result... skipping
# Retrieving results for index 74: [row['City']
# Missing field/result... skipping
# Retrieving results for index 75: [row['City']
# Missing field/result... skipping
# Retrieving results for index 76: [row['City']
# Missing field/result... skipping
# Retrieving results for index 77: [row['City']
# Missing field/result... skipping
# Retrieving results for index 78: [row['City']
# Missing field/result... skipping
# Retrieving results for index 79: [row['City']
# Missing field/result... skipping
# Retrieving results for index 80: [row['City']
# Missing field/result... skipping
# Retrieving results for index 81: [row['City']
# Missing field/result... skipping
# Retrieving results for index 82: [row['City']
# Missing field/result... skipping
# Retrieving results for index 83: [row['City']
# Missing field/result... skipping
# Retrieving results for index 84: [row['City']
# Missing field/result... skipping
# Retrieving results for index 85: [row['City']
# Missing field/result... skipping
# Retrieving results for index 86: [row['City']
# Missing field/result... skipping
# Retrieving results for index 87: [row['City']
# Missing field/result... skipping
# Retrieving results for index 88: [row['City']
# Missing field/result... skipping
# Retrieving results for index 89: [row['City']
# Missing field/result... skipping
# Retrieving results for index 90: [row['City']
# Missing field/result... skipping
# Retrieving results for index 91: [row['City']
# Missing field/result... skipping
# Retrieving results for index 92: [row['City']
# Missing field/result... skipping
# Retrieving results for index 93: [row['City']
# Missing field/result... skipping
# Retrieving results for index 94: [row['City']
# Missing field/result... skipping
# Retrieving results for index 95: [row['City']
# Missing field/result... skipping
# Retrieving results for index 96: [row['City']
# Missing field/result... skipping
# Retrieving results for index 97: [row['City']
# Missing field/result... skipping
# Retrieving results for index 98: [row['City']
# Missing field/result... skipping
# Retrieving results for index 99: [row['City']
# Missing field/result... skipping
# Retrieving results for index 100: [row['City']
# Missing field/result... skipping
# Retrieving results for index 101: [row['City']
# Missing field/result... skipping
# Retrieving results for index 102: [row['City']
# Missing field/result... skipping
# Retrieving results for index 103: [row['City']
# Missing field/result... skipping
# Retrieving results for index 104: [row['City']
# Missing field/result... skipping
# Retrieving results for index 105: [row['City']
# Missing field/result... skipping
# Retrieving results for index 106: [row['City']
# Missing field/result... skipping
# Retrieving results for index 107: [row['City']
# Missing field/result... skipping
# Retrieving results for index 108: [row['City']
# Missing field/result... skipping
# Retrieving results for index 109: [row['City']
# Missing field/result... skipping
# Retrieving results for index 110: [row['City']
# Missing field/result... skipping
# Retrieving results for index 111: [row['City']
# Missing field/result... skipping
# Retrieving results for index 112: [row['City']
# Missing field/result... skipping
# Retrieving results for index 113: [row['City']
# Missing field/result... skipping
# Retrieving results for index 114: [row['City']
# Missing field/result... skipping
# Retrieving results for index 115: [row['City']
# Missing field/result... skipping
# Retrieving results for index 116: [row['City']
# Missing field/result... skipping
# Retrieving results for index 117: [row['City']
# Missing field/result... skipping
# Retrieving results for index 118: [row['City']
# Missing field/result... skipping
# Retrieving results for index 119: [row['City']
# Missing field/result... skipping
# Retrieving results for index 120: [row['City']
# Missing field/result... skipping
# Retrieving results for index 121: [row['City']
# Missing field/result... skipping
# Retrieving results for index 122: [row['City']
# Missing field/result... skipping
# Retrieving results for index 123: [row['City']
# Missing field/result... skipping
# Retrieving results for index 124: [row['City']
# Missing field/result... skipping
# Retrieving results for index 125: [row['City']
# Missing field/result... skipping
# Retrieving results for index 126: [row['City']
# Missing field/result... skipping
# Retrieving results for index 127: [row['City']
# Missing field/result... skipping
# Retrieving results for index 128: [row['City']
# Missing field/result... skipping
# Retrieving results for index 129: [row['City']
# Missing field/result... skipping
# Retrieving results for index 130: [row['City']
# Missing field/result... skipping
# Retrieving results for index 131: [row['City']
# Missing field/result... skipping
# Retrieving results for index 132: [row['City']
# Missing field/result... skipping
# Retrieving results for index 133: [row['City']
# Missing field/result... skipping
# Retrieving results for index 134: [row['City']
# Missing field/result... skipping
# Retrieving results for index 135: [row['City']
# Missing field/result... skipping
# Retrieving results for index 136: [row['City']
# Missing field/result... skipping
# Retrieving results for index 137: [row['City']
# Missing field/result... skipping
# Retrieving results for index 138: [row['City']
# Missing field/result... skipping
# Retrieving results for index 139: [row['City']
# Missing field/result... skipping
# Retrieving results for index 140: [row['City']
# Missing field/result... skipping
# Retrieving results for index 141: [row['City']
# Missing field/result... skipping
# Retrieving results for index 142: [row['City']
# Missing field/result... skipping
# Retrieving results for index 143: [row['City']
# Missing field/result... skipping
# Retrieving results for index 144: [row['City']
# Missing field/result... skipping
# Retrieving results for index 145: [row['City']
# Missing field/result... skipping
# Retrieving results for index 146: [row['City']
# Missing field/result... skipping
# Retrieving results for index 147: [row['City']
# Missing field/result... skipping
# Retrieving results for index 148: [row['City']
# Missing field/result... skipping
# Retrieving results for index 149: [row['City']
# Missing field/result... skipping
# Retrieving results for index 150: [row['City']
# Missing field/result... skipping
# Retrieving results for index 151: [row['City']
# Missing field/result... skipping
# Retrieving results for index 152: [row['City']
# Missing field/result... skipping
# Retrieving results for index 153: [row['City']
# Missing field/result... skipping
# Retrieving results for index 154: [row['City']
# Missing field/result... skipping
# Retrieving results for index 155: [row['City']
# Missing field/result... skipping
# Retrieving results for index 156: [row['City']
# Missing field/result... skipping
# Retrieving results for index 157: [row['City']
# Missing field/result... skipping
# Retrieving results for index 158: [row['City']
# Missing field/result... skipping
# Retrieving results for index 159: [row['City']
# Missing field/result... skipping
# Retrieving results for index 160: [row['City']
# Missing field/result... skipping
# Retrieving results for index 161: [row['City']
# Missing field/result... skipping
# Retrieving results for index 162: [row['City']
# Missing field/result... skipping
# Retrieving results for index 163: [row['City']
# Missing field/result... skipping
# Retrieving results for index 164: [row['City']
# Missing field/result... skipping
# Retrieving results for index 165: [row['City']
# Missing field/result... skipping
# Retrieving results for index 166: [row['City']
# Missing field/result... skipping
# Retrieving results for index 167: [row['City']
# Missing field/result... skipping
# Retrieving results for index 168: [row['City']
# Missing field/result... skipping
# Retrieving results for index 169: [row['City']
# Missing field/result... skipping
# Retrieving results for index 170: [row['City']
# Missing field/result... skipping
# Retrieving results for index 171: [row['City']
# Missing field/result... skipping
# Retrieving results for index 172: [row['City']
# Missing field/result... skipping
# Retrieving results for index 173: [row['City']
# Missing field/result... skipping
# Retrieving results for index 174: [row['City']
# Missing field/result... skipping
# Retrieving results for index 175: [row['City']
# Missing field/result... skipping
# Retrieving results for index 176: [row['City']
# Missing field/result... skipping
# Retrieving results for index 177: [row['City']
# Missing field/result... skipping
# Retrieving results for index 178: [row['City']
# Missing field/result... skipping
# Retrieving results for index 179: [row['City']
# Missing field/result... skipping
# Retrieving results for index 180: [row['City']
# Missing field/result... skipping
# Retrieving results for index 181: [row['City']
# Missing field/result... skipping
# Retrieving results for index 182: [row['City']
# Missing field/result... skipping
# Retrieving results for index 183: [row['City']
# Missing field/result... skipping
# Retrieving results for index 184: [row['City']
# Missing field/result... skipping
# Retrieving results for index 185: [row['City']
# Missing field/result... skipping
# Retrieving results for index 186: [row['City']
# Missing field/result... skipping
# Retrieving results for index 187: [row['City']
# Missing field/result... skipping
# Retrieving results for index 188: [row['City']
# Missing field/result... skipping
# Retrieving results for index 189: [row['City']
# Missing field/result... skipping
# Retrieving results for index 190: [row['City']
# Missing field/result... skipping
# Retrieving results for index 191: [row['City']
# Missing field/result... skipping
# Retrieving results for index 192: [row['City']
# Missing field/result... skipping
# Retrieving results for index 193: [row['City']
# Missing field/result... skipping
# Retrieving results for index 194: [row['City']
# Missing field/result... skipping
# Retrieving results for index 195: [row['City']
# Missing field/result... skipping
# Retrieving results for index 196: [row['City']
# Missing field/result... skipping
# Retrieving results for index 197: [row['City']
# Missing field/result... skipping
# Retrieving results for index 198: [row['City']
# Missing field/result... skipping
# Retrieving results for index 199: [row['City']
# Missing field/result... skipping
# Retrieving results for index 200: [row['City']
# Missing field/result... skipping
# Retrieving results for index 201: [row['City']
# Missing field/result... skipping
# Retrieving results for index 202: [row['City']
# Missing field/result... skipping
# Retrieving results for index 203: [row['City']
# Missing field/result... skipping
# Retrieving results for index 204: [row['City']
# Missing field/result... skipping
# Retrieving results for index 205: [row['City']
# Missing field/result... skipping
# Retrieving results for index 206: [row['City']
# Missing field/result... skipping
# Retrieving results for index 207: [row['City']
# Missing field/result... skipping
# Retrieving results for index 208: [row['City']
# Missing field/result... skipping
# Retrieving results for index 209: [row['City']
# Missing field/result... skipping
# Retrieving results for index 210: [row['City']
# Missing field/result... skipping
# Retrieving results for index 211: [row['City']
# Missing field/result... skipping
# Retrieving results for index 212: [row['City']
# Missing field/result... skipping
# Retrieving results for index 213: [row['City']
# Missing field/result... skipping
# Retrieving results for index 214: [row['City']
# Missing field/result... skipping
# Retrieving results for index 215: [row['City']
# Missing field/result... skipping
# Retrieving results for index 216: [row['City']
# Missing field/result... skipping
# Retrieving results for index 217: [row['City']
# Missing field/result... skipping
# Retrieving results for index 218: [row['City']
# Missing field/result... skipping
# Retrieving results for index 219: [row['City']
# Missing field/result... skipping
# Retrieving results for index 220: [row['City']
# Missing field/result... skipping
# Retrieving results for index 221: [row['City']
# Missing field/result... skipping
# Retrieving results for index 222: [row['City']
# Missing field/result... skipping
# Retrieving results for index 223: [row['City']
# Missing field/result... skipping
# Retrieving results for index 224: [row['City']
# Missing field/result... skipping
# Retrieving results for index 225: [row['City']
# Missing field/result... skipping
# Retrieving results for index 226: [row['City']
# Missing field/result... skipping
# Retrieving results for index 227: [row['City']
# Missing field/result... skipping
# Retrieving results for index 228: [row['City']
# Missing field/result... skipping
# Retrieving results for index 229: [row['City']
# Missing field/result... skipping
# Retrieving results for index 230: [row['City']
# Missing field/result... skipping
# Retrieving results for index 231: [row['City']
# Missing field/result... skipping
# Retrieving results for index 232: [row['City']
# Missing field/result... skipping
# Retrieving results for index 233: [row['City']
# Missing field/result... skipping
# Retrieving results for index 234: [row['City']
# Missing field/result... skipping
# Retrieving results for index 235: [row['City']
# Missing field/result... skipping
# Retrieving results for index 236: [row['City']
# Missing field/result... skipping
# Retrieving results for index 237: [row['City']
# Missing field/result... skipping
# Retrieving results for index 238: [row['City']
# Missing field/result... skipping
# Retrieving results for index 239: [row['City']
# Missing field/result... skipping
# Retrieving results for index 240: [row['City']
# Missing field/result... skipping
# Retrieving results for index 241: [row['City']
# Missing field/result... skipping
# Retrieving results for index 242: [row['City']
# Missing field/result... skipping
# Retrieving results for index 243: [row['City']
# Missing field/result... skipping
# Retrieving results for index 244: [row['City']
# Missing field/result... skipping
# Retrieving results for index 245: [row['City']
# Missing field/result... skipping
# Retrieving results for index 246: [row['City']
# Missing field/result... skipping
# Retrieving results for index 247: [row['City']
# Missing field/result... skipping
# Retrieving results for index 248: [row['City']
# Missing field/result... skipping
# Retrieving results for index 249: [row['City']
# Missing field/result... skipping
# Retrieving results for index 250: [row['City']
# Missing field/result... skipping
# Retrieving results for index 251: [row['City']
# Missing field/result... skipping
# Retrieving results for index 252: [row['City']
# Missing field/result... skipping
# Retrieving results for index 253: [row['City']
# Missing field/result... skipping
# Retrieving results for index 254: [row['City']
# Missing field/result... skipping
# Retrieving results for index 255: [row['City']
# Missing field/result... skipping
# Retrieving results for index 256: [row['City']
# Missing field/result... skipping
# Retrieving results for index 257: [row['City']
# Missing field/result... skipping
# Retrieving results for index 258: [row['City']
# Missing field/result... skipping
# Retrieving results for index 259: [row['City']
# Missing field/result... skipping
# Retrieving results for index 260: [row['City']
# Missing field/result... skipping
# Retrieving results for index 261: [row['City']
# Missing field/result... skipping
# Retrieving results for index 262: [row['City']
# Missing field/result... skipping
# Retrieving results for index 263: [row['City']
# Missing field/result... skipping
# Retrieving results for index 264: [row['City']
# Missing field/result... skipping
# Retrieving results for index 265: [row['City']
# Missing field/result... skipping
# Retrieving results for index 266: [row['City']
# Missing field/result... skipping
# Retrieving results for index 267: [row['City']
# Missing field/result... skipping
# Retrieving results for index 268: [row['City']
# Missing field/result... skipping
# Retrieving results for index 269: [row['City']
# Missing field/result... skipping
# Retrieving results for index 270: [row['City']
# Missing field/result... skipping
# Retrieving results for index 271: [row['City']
# Missing field/result... skipping
# Retrieving results for index 272: [row['City']
# Missing field/result... skipping
# Retrieving results for index 273: [row['City']
# Missing field/result... skipping
# Retrieving results for index 274: [row['City']
# Missing field/result... skipping
# Retrieving results for index 275: [row['City']
# Missing field/result... skipping
# Retrieving results for index 276: [row['City']
# Missing field/result... skipping
# Retrieving results for index 277: [row['City']
# Missing field/result... skipping
# Retrieving results for index 278: [row['City']
# Missing field/result... skipping
# Retrieving results for index 279: [row['City']
# Missing field/result... skipping
# Retrieving results for index 280: [row['City']
# Missing field/result... skipping
# Retrieving results for index 281: [row['City']
# Missing field/result... skipping
# Retrieving results for index 282: [row['City']
# Missing field/result... skipping
# Retrieving results for index 283: [row['City']
# Missing field/result... skipping
# Retrieving results for index 284: [row['City']
# Missing field/result... skipping
# Retrieving results for index 285: [row['City']
# Missing field/result... skipping
# Retrieving results for index 286: [row['City']
# Missing field/result... skipping
# Retrieving results for index 287: [row['City']
# Missing field/result... skipping
# Retrieving results for index 288: [row['City']
# Missing field/result... skipping
# Retrieving results for index 289: [row['City']
# Missing field/result... skipping
# Retrieving results for index 290: [row['City']
# Missing field/result... skipping
# Retrieving results for index 291: [row['City']
# Missing field/result... skipping
# Retrieving results for index 292: [row['City']
# Missing field/result... skipping
# Retrieving results for index 293: [row['City']
# Missing field/result... skipping
# Retrieving results for index 294: [row['City']
# Missing field/result... skipping
# Retrieving results for index 295: [row['City']
# Missing field/result... skipping
# Retrieving results for index 296: [row['City']
# Missing field/result... skipping
# Retrieving results for index 297: [row['City']
# Missing field/result... skipping
# Retrieving results for index 298: [row['City']
# Missing field/result... skipping
# Retrieving results for index 299: [row['City']
# Missing field/result... skipping
# Retrieving results for index 300: [row['City']
# Missing field/result... skipping
# Retrieving results for index 301: [row['City']
# Missing field/result... skipping
# Retrieving results for index 302: [row['City']
# Missing field/result... skipping
# Retrieving results for index 303: [row['City']
# Missing field/result... skipping
# Retrieving results for index 304: [row['City']
# Missing field/result... skipping
# Retrieving results for index 305: [row['City']
# Missing field/result... skipping
# Retrieving results for index 306: [row['City']
# Missing field/result... skipping
# Retrieving results for index 307: [row['City']
# Missing field/result... skipping
# Retrieving results for index 308: [row['City']
# Missing field/result... skipping
# Retrieving results for index 309: [row['City']
# Missing field/result... skipping
# Retrieving results for index 310: [row['City']
# Missing field/result... skipping
# Retrieving results for index 311: [row['City']
# Missing field/result... skipping
# Retrieving results for index 312: [row['City']
# Missing field/result... skipping
# Retrieving results for index 313: [row['City']
# Missing field/result... skipping
# Retrieving results for index 314: [row['City']
# Missing field/result... skipping
# Retrieving results for index 315: [row['City']
# Missing field/result... skipping
# Retrieving results for index 316: [row['City']
# Missing field/result... skipping
# Retrieving results for index 317: [row['City']
# Missing field/result... skipping
# Retrieving results for index 318: [row['City']
# Missing field/result... skipping
# Retrieving results for index 319: [row['City']
# Missing field/result... skipping
# Retrieving results for index 320: [row['City']
# Missing field/result... skipping
# Retrieving results for index 321: [row['City']
# Missing field/result... skipping
# Retrieving results for index 322: [row['City']
# Missing field/result... skipping
# Retrieving results for index 323: [row['City']
# Missing field/result... skipping
# Retrieving results for index 324: [row['City']
# Missing field/result... skipping
# Retrieving results for index 325: [row['City']
# Missing field/result... skipping
# Retrieving results for index 326: [row['City']
# Missing field/result... skipping
# Retrieving results for index 327: [row['City']
# Missing field/result... skipping
# Retrieving results for index 328: [row['City']
# Missing field/result... skipping
# Retrieving results for index 329: [row['City']
# Missing field/result... skipping
# Retrieving results for index 330: [row['City']
# Missing field/result... skipping
# Retrieving results for index 331: [row['City']
# Missing field/result... skipping
# Retrieving results for index 332: [row['City']
# Missing field/result... skipping
# Retrieving results for index 333: [row['City']
# Missing field/result... skipping
# Retrieving results for index 334: [row['City']
# Missing field/result... skipping
# Retrieving results for index 335: [row['City']
# Missing field/result... skipping
# Retrieving results for index 336: [row['City']
# Missing field/result... skipping
# Retrieving results for index 337: [row['City']
# Missing field/result... skipping
# Retrieving results for index 338: [row['City']
# Missing field/result... skipping
# Retrieving results for index 339: [row['City']
# Missing field/result... skipping
# Retrieving results for index 340: [row['City']
# Missing field/result... skipping
# Retrieving results for index 341: [row['City']
# Missing field/result... skipping
# Retrieving results for index 342: [row['City']
# Missing field/result... skipping
# Retrieving results for index 343: [row['City']
# Missing field/result... skipping
# Retrieving results for index 344: [row['City']
# Missing field/result... skipping
# Retrieving results for index 345: [row['City']
# Missing field/result... skipping
# Retrieving results for index 346: [row['City']
# Missing field/result... skipping
# Retrieving results for index 347: [row['City']
# Missing field/result... skipping
# Retrieving results for index 348: [row['City']
# Missing field/result... skipping
# Retrieving results for index 349: [row['City']
# Missing field/result... skipping
# Retrieving results for index 350: [row['City']
# Missing field/result... skipping
# Retrieving results for index 351: [row['City']
# Missing field/result... skipping
# Retrieving results for index 352: [row['City']
# Missing field/result... skipping
# Retrieving results for index 353: [row['City']
# Missing field/result... skipping
# Retrieving results for index 354: [row['City']
# Missing field/result... skipping
# Retrieving results for index 355: [row['City']
# Missing field/result... skipping
# Retrieving results for index 356: [row['City']
# Missing field/result... skipping
# Retrieving results for index 357: [row['City']
# Missing field/result... skipping
# Retrieving results for index 358: [row['City']
# Missing field/result... skipping
# Retrieving results for index 359: [row['City']
# Missing field/result... skipping
# Retrieving results for index 360: [row['City']
# Missing field/result... skipping
# Retrieving results for index 361: [row['City']
# Missing field/result... skipping
# Retrieving results for index 362: [row['City']
# Missing field/result... skipping
# Retrieving results for index 363: [row['City']
# Missing field/result... skipping
# Retrieving results for index 364: [row['City']
# Missing field/result... skipping
# Retrieving results for index 365: [row['City']
# Missing field/result... skipping
# Retrieving results for index 366: [row['City']
# Missing field/result... skipping
# Retrieving results for index 367: [row['City']
# Missing field/result... skipping
# Retrieving results for index 368: [row['City']
# Missing field/result... skipping
# Retrieving results for index 369: [row['City']
# Missing field/result... skipping
# Retrieving results for index 370: [row['City']
# Missing field/result... skipping
# Retrieving results for index 371: [row['City']
# Missing field/result... skipping
# Retrieving results for index 372: [row['City']
# Missing field/result... skipping
# Retrieving results for index 373: [row['City']
# Missing field/result... skipping
# Retrieving results for index 374: [row['City']
# Missing field/result... skipping
# Retrieving results for index 375: [row['City']
# Missing field/result... skipping
# Retrieving results for index 376: [row['City']
# Missing field/result... skipping
# Retrieving results for index 377: [row['City']
# Missing field/result... skipping
# Retrieving results for index 378: [row['City']
# Missing field/result... skipping
# Retrieving results for index 379: [row['City']
# Missing field/result... skipping
# Retrieving results for index 380: [row['City']
# Missing field/result... skipping
# Retrieving results for index 381: [row['City']
# Missing field/result... skipping
# Retrieving results for index 382: [row['City']
# Missing field/result... skipping
# Retrieving results for index 383: [row['City']
# Missing field/result... skipping
# Retrieving results for index 384: [row['City']
# Missing field/result... skipping
# Retrieving results for index 385: [row['City']
# Missing field/result... skipping
# Retrieving results for index 386: [row['City']
# Missing field/result... skipping
# Retrieving results for index 387: [row['City']
# Missing field/result... skipping
# Retrieving results for index 388: [row['City']
# Missing field/result... skipping
# Retrieving results for index 389: [row['City']
# Missing field/result... skipping
# Retrieving results for index 390: [row['City']
# Missing field/result... skipping
# Retrieving results for index 391: [row['City']
# Missing field/result... skipping
# Retrieving results for index 392: [row['City']
# Missing field/result... skipping
# Retrieving results for index 393: [row['City']
# Missing field/result... skipping
# Retrieving results for index 394: [row['City']
# Missing field/result... skipping
# Retrieving results for index 395: [row['City']
# Missing field/result... skipping
# Retrieving results for index 396: [row['City']
# Missing field/result... skipping
# Retrieving results for index 397: [row['City']
# Missing field/result... skipping
# Retrieving results for index 398: [row['City']
# Missing field/result... skipping
# Retrieving results for index 399: [row['City']
# Missing field/result... skipping
# Retrieving results for index 400: [row['City']
# Missing field/result... skipping
# Retrieving results for index 401: [row['City']
# Missing field/result... skipping
# Retrieving results for index 402: [row['City']
# Missing field/result... skipping
# Retrieving results for index 403: [row['City']
# Missing field/result... skipping
# Retrieving results for index 404: [row['City']
# Missing field/result... skipping
# Retrieving results for index 405: [row['City']
# Missing field/result... skipping
# Retrieving results for index 406: [row['City']
# Missing field/result... skipping
# Retrieving results for index 407: [row['City']
# Missing field/result... skipping
# Retrieving results for index 408: [row['City']
# Missing field/result... skipping
# Retrieving results for index 409: [row['City']
# Missing field/result... skipping
# Retrieving results for index 410: [row['City']
# Missing field/result... skipping
# Retrieving results for index 411: [row['City']
# Missing field/result... skipping
# Retrieving results for index 412: [row['City']
# Missing field/result... skipping
# Retrieving results for index 413: [row['City']
# Missing field/result... skipping
# Retrieving results for index 414: [row['City']
# Missing field/result... skipping
# Retrieving results for index 415: [row['City']
# Missing field/result... skipping
# Retrieving results for index 416: [row['City']
# Missing field/result... skipping
# Retrieving results for index 417: [row['City']
# Missing field/result... skipping
# Retrieving results for index 418: [row['City']
# Missing field/result... skipping
# Retrieving results for index 419: [row['City']
# Missing field/result... skipping
# Retrieving results for index 420: [row['City']
# Missing field/result... skipping
# Retrieving results for index 421: [row['City']
# Missing field/result... skipping
# Retrieving results for index 422: [row['City']
# Missing field/result... skipping
# Retrieving results for index 423: [row['City']
# Missing field/result... skipping
# Retrieving results for index 424: [row['City']
# Missing field/result... skipping
# Retrieving results for index 425: [row['City']
# Missing field/result... skipping
# Retrieving results for index 426: [row['City']
# Missing field/result... skipping
# Retrieving results for index 427: [row['City']
# Missing field/result... skipping
# Retrieving results for index 428: [row['City']
# Missing field/result... skipping
# Retrieving results for index 429: [row['City']
# Missing field/result... skipping
# Retrieving results for index 430: [row['City']
# Missing field/result... skipping
# Retrieving results for index 431: [row['City']
# Missing field/result... skipping
# Retrieving results for index 432: [row['City']
# Missing field/result... skipping
# Retrieving results for index 433: [row['City']
# Missing field/result... skipping
# Retrieving results for index 434: [row['City']
# Missing field/result... skipping
# Retrieving results for index 435: [row['City']
# Missing field/result... skipping
# Retrieving results for index 436: [row['City']
# Missing field/result... skipping
# Retrieving results for index 437: [row['City']
# Missing field/result... skipping
# Retrieving results for index 438: [row['City']
# Missing field/result... skipping
# Retrieving results for index 439: [row['City']
# Missing field/result... skipping
# Retrieving results for index 440: [row['City']
# Missing field/result... skipping
# Retrieving results for index 441: [row['City']
# Missing field/result... skipping
# Retrieving results for index 442: [row['City']
# Missing field/result... skipping
# Retrieving results for index 443: [row['City']
# Missing field/result... skipping
# Retrieving results for index 444: [row['City']
# Missing field/result... skipping
# Retrieving results for index 445: [row['City']
# Missing field/result... skipping
# Retrieving results for index 446: [row['City']
# Missing field/result... skipping
# Retrieving results for index 447: [row['City']
# Missing field/result... skipping
# Retrieving results for index 448: [row['City']
# Missing field/result... skipping
# Retrieving results for index 449: [row['City']
# Missing field/result... skipping
# Retrieving results for index 450: [row['City']
# Missing field/result... skipping
# Retrieving results for index 451: [row['City']
# Missing field/result... skipping
# Retrieving results for index 452: [row['City']
# Missing field/result... skipping
# Retrieving results for index 453: [row['City']
# Missing field/result... skipping
# Retrieving results for index 454: [row['City']
# Missing field/result... skipping
# Retrieving results for index 455: [row['City']
# Missing field/result... skipping
# Retrieving results for index 456: [row['City']
# Missing field/result... skipping
# Retrieving results for index 457: [row['City']
# Missing field/result... skipping
# Retrieving results for index 458: [row['City']
# Missing field/result... skipping
# Retrieving results for index 459: [row['City']
# Missing field/result... skipping
# Retrieving results for index 460: [row['City']
# Missing field/result... skipping
# Retrieving results for index 461: [row['City']
# Missing field/result... skipping
# Retrieving results for index 462: [row['City']
# Missing field/result... skipping
# Retrieving results for index 463: [row['City']
# Missing field/result... skipping
# Retrieving results for index 464: [row['City']
# Missing field/result... skipping
# Retrieving results for index 465: [row['City']
# Missing field/result... skipping
# Retrieving results for index 466: [row['City']
# Missing field/result... skipping
# Retrieving results for index 467: [row['City']
# Missing field/result... skipping
# Retrieving results for index 468: [row['City']
# Missing field/result... skipping
# Retrieving results for index 469: [row['City']
# Missing field/result... skipping
# Retrieving results for index 470: [row['City']
# Missing field/result... skipping
# Retrieving results for index 471: [row['City']
# Missing field/result... skipping
# Retrieving results for index 472: [row['City']
# Missing field/result... skipping
# Retrieving results for index 473: [row['City']
# Missing field/result... skipping
# Retrieving results for index 474: [row['City']
# Missing field/result... skipping
# Retrieving results for index 475: [row['City']
# Missing field/result... skipping
# Retrieving results for index 476: [row['City']
# Missing field/result... skipping
# Retrieving results for index 477: [row['City']
# Missing field/result... skipping
# Retrieving results for index 478: [row['City']
# Missing field/result... skipping
# Retrieving results for index 479: [row['City']
# Missing field/result... skipping
# Retrieving results for index 480: [row['City']
# Missing field/result... skipping
# Retrieving results for index 481: [row['City']
# Missing field/result... skipping
# Retrieving results for index 482: [row['City']
# Missing field/result... skipping
# Retrieving results for index 483: [row['City']
# Missing field/result... skipping
# Retrieving results for index 484: [row['City']
# Missing field/result... skipping
# Retrieving results for index 485: [row['City']
# Missing field/result... skipping
# Retrieving results for index 486: [row['City']
# Missing field/result... skipping
# Retrieving results for index 487: [row['City']
# Missing field/result... skipping
# Retrieving results for index 488: [row['City']
# Missing field/result... skipping
# Retrieving results for index 489: [row['City']
# Missing field/result... skipping
# Retrieving results for index 490: [row['City']
# Missing field/result... skipping
# Retrieving results for index 491: [row['City']
# Missing field/result... skipping
# Retrieving results for index 492: [row['City']
# Missing field/result... skipping
# Retrieving results for index 493: [row['City']
# Missing field/result... skipping
# Retrieving results for index 494: [row['City']
# Missing field/result... skipping
# Retrieving results for index 495: [row['City']
# Missing field/result... skipping
# Retrieving results for index 496: [row['City']
# Missing field/result... skipping
# Retrieving results for index 497: [row['City']
# Missing field/result... skipping
# Retrieving results for index 498: [row['City']
# Missing field/result... skipping
# Retrieving results for index 499: [row['City']
# Missing field/result... skipping
# Retrieving results for index 500: [row['City']
# Missing field/result... skipping
# Retrieving results for index 501: [row['City']
# Missing field/result... skipping
# Retrieving results for index 502: [row['City']
# Missing field/result... skipping
# Retrieving results for index 503: [row['City']
# Missing field/result... skipping
# Retrieving results for index 504: [row['City']
# Missing field/result... skipping
# Retrieving results for index 505: [row['City']
# Missing field/result... skipping
# Retrieving results for index 506: [row['City']
# Missing field/result... skipping
# Retrieving results for index 507: [row['City']
# Missing field/result... skipping
# Retrieving results for index 508: [row['City']
# Missing field/result... skipping
# Retrieving results for index 509: [row['City']
# Missing field/result... skipping
# Retrieving results for index 510: [row['City']
# Missing field/result... skipping
# Retrieving results for index 511: [row['City']
# Missing field/result... skipping
# Retrieving results for index 512: [row['City']
# Missing field/result... skipping
# Retrieving results for index 513: [row['City']
# Missing field/result... skipping
# Retrieving results for index 514: [row['City']
# Missing field/result... skipping
# Retrieving results for index 515: [row['City']
# Missing field/result... skipping
# Retrieving results for index 516: [row['City']
# Missing field/result... skipping
# Retrieving results for index 517: [row['City']
# Missing field/result... skipping
# Retrieving results for index 518: [row['City']
# Missing field/result... skipping
# Retrieving results for index 519: [row['City']
# Missing field/result... skipping
# Retrieving results for index 520: [row['City']
# Missing field/result... skipping
# Retrieving results for index 521: [row['City']
# Missing field/result... skipping
# Retrieving results for index 522: [row['City']
# Missing field/result... skipping
# Retrieving results for index 523: [row['City']
# Missing field/result... skipping
# Retrieving results for index 524: [row['City']
# Missing field/result... skipping
# Retrieving results for index 525: [row['City']
# Missing field/result... skipping
# Retrieving results for index 526: [row['City']
# Missing field/result... skipping
# Retrieving results for index 527: [row['City']
# Missing field/result... skipping
# Retrieving results for index 528: [row['City']
# Missing field/result... skipping
# Retrieving results for index 529: [row['City']
# Missing field/result... skipping
# Retrieving results for index 530: [row['City']
# Missing field/result... skipping
# Retrieving results for index 531: [row['City']
# Missing field/result... skipping
# Retrieving results for index 532: [row['City']
# Missing field/result... skipping
# Retrieving results for index 533: [row['City']
# Missing field/result... skipping
# Retrieving results for index 534: [row['City']
# Missing field/result... skipping
# Retrieving results for index 535: [row['City']
# Missing field/result... skipping
# Retrieving results for index 536: [row['City']
# Missing field/result... skipping
# Retrieving results for index 537: [row['City']
# Missing field/result... skipping
# Retrieving results for index 538: [row['City']
# Missing field/result... skipping
# Retrieving results for index 539: [row['City']
# Missing field/result... skipping
# Retrieving results for index 540: [row['City']
# Missing field/result... skipping
# Retrieving results for index 541: [row['City']
# Missing field/result... skipping
# Retrieving results for index 542: [row['City']
# Missing field/result... skipping
# Retrieving results for index 543: [row['City']
# Missing field/result... skipping
# Retrieving results for index 544: [row['City']
# Missing field/result... skipping
# Retrieving results for index 545: [row['City']
# Missing field/result... skipping
# Retrieving results for index 546: [row['City']
# Missing field/result... skipping
# Retrieving results for index 547: [row['City']
# Missing field/result... skipping
# Retrieving results for index 548: [row['City']
# Missing field/result... skipping
# Retrieving results for index 549: [row['City']
# Missing field/result... skipping
# Retrieving results for index 550: [row['City']
# Missing field/result... skipping
# Retrieving results for index 551: [row['City']
# Missing field/result... skipping
# Retrieving results for index 552: [row['City']
# Missing field/result... skipping
# Retrieving results for index 553: [row['City']
# Missing field/result... skipping
# Retrieving results for index 554: [row['City']
# Missing field/result... skipping
# Retrieving results for index 555: [row['City']
# Missing field/result... skipping
# Retrieving results for index 556: [row['City']
# Missing field/result... skipping
# Retrieving results for index 557: [row['City']
# Missing field/result... skipping
# Retrieving results for index 558: [row['City']
# Missing field/result... skipping
# Retrieving results for index 559: [row['City']
# Missing field/result... skipping
# Retrieving results for index 560: [row['City']
# Missing field/result... skipping
# Retrieving results for index 561: [row['City']
# Missing field/result... skipping
# Retrieving results for index 562: [row['City']
# Missing field/result... skipping
# Retrieving results for index 563: [row['City']
# Missing field/result... skipping
# Retrieving results for index 564: [row['City']
# Missing field/result... skipping
# Retrieving results for index 565: [row['City']
# Missing field/result... skipping
# Retrieving results for index 566: [row['City']
# Missing field/result... skipping
# Retrieving results for index 567: [row['City']
# Missing field/result... skipping
# Retrieving results for index 568: [row['City']
# Missing field/result... skipping
# Retrieving results for index 569: [row['City']
# Missing field/result... skipping
# Retrieving results for index 570: [row['City']
# Missing field/result... skipping
# Retrieving results for index 571: [row['City']
# Missing field/result... skipping
# Retrieving results for index 572: [row['City']
# Missing field/result... skipping
# Retrieving results for index 573: [row['City']
# Missing field/result... skipping
# Retrieving results for index 574: [row['City']
# Missing field/result... skipping
# Retrieving results for index 575: [row['City']
# Missing field/result... skipping
# Retrieving results for index 576: [row['City']
# Missing field/result... skipping
# Retrieving results for index 577: [row['City']
# Missing field/result... skipping
# Retrieving results for index 578: [row['City']
# Missing field/result... skipping
# Retrieving results for index 579: [row['City']
# Missing field/result... skipping
# Retrieving results for index 580: [row['City']
# Missing field/result... skipping
# Retrieving results for index 581: [row['City']
# Missing field/result... skipping
# Retrieving results for index 582: [row['City']
# Missing field/result... skipping
# Retrieving results for index 583: [row['City']
# Missing field/result... skipping
# Retrieving results for index 584: [row['City']
# Missing field/result... skipping
# Retrieving results for index 585: [row['City']
# Missing field/result... skipping
# Retrieving results for index 586: [row['City']
# Missing field/result... skipping
# Retrieving results for index 587: [row['City']
# Missing field/result... skipping
# Retrieving results for index 588: [row['City']
# Missing field/result... skipping
# Retrieving results for index 589: [row['City']
# Missing field/result... skipping
# Retrieving results for index 590: [row['City']
# Missing field/result... skipping
# Retrieving results for index 591: [row['City']
# Missing field/result... skipping
# Retrieving results for index 592: [row['City']
# Missing field/result... skipping
# Retrieving results for index 593: [row['City']
# Missing field/result... skipping
# Retrieving results for index 594: [row['City']
# Missing field/result... skipping
# Retrieving results for index 595: [row['City']
# Missing field/result... skipping
# Retrieving results for index 596: [row['City']
# Missing field/result... skipping
# Retrieving results for index 597: [row['City']
# Missing field/result... skipping
# Retrieving results for index 598: [row['City']
# Missing field/result... skipping
# Retrieving results for index 599: [row['City']
# Missing field/result... skipping
# Retrieving results for index 600: [row['City']
# Missing field/result... skipping
# Retrieving results for index 601: [row['City']
# Missing field/result... skipping
# Retrieving results for index 602: [row['City']
# Missing field/result... skipping
# Retrieving results for index 603: [row['City']
# Missing field/result... skipping
# Retrieving results for index 604: [row['City']
# Missing field/result... skipping
# Retrieving results for index 605: [row['City']
# Missing field/result... skipping
# Retrieving results for index 606: [row['City']
# Missing field/result... skipping
# Retrieving results for index 607: [row['City']
# Missing field/result... skipping
# Retrieving results for index 608: [row['City']
# Missing field/result... skipping
#    Unnamed: 0             City Lat Temp Humidity Cloudiness Wind Speed
# 0           0        busselton
# 1           1           atuona
# 2           2          mataura
# 3           3  arraial do cabo
# 4           4   ribeira grande

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# settings = {'units': 'metric', 'appid': api_key}
# weather_data = []
# try:
#     with open('../Resources/cities.csv') as cities_file:
#         cities_reader = csv.reader(cities_file)
#         cities = [city[0] for city in cities_reader]
#         weather_data = [ow.get_current(city, **settings) for city in cities]
# except Exception as error:
#     print(f"Unexpected Error: {type(error)} {error}")

# summary = ["main.temp", "coord.lat", "coord.lon"]

# data = [response(*summary) for response in weather_data]
# weather_data_pd = pd.DataFrame(data, index=cities)
# weather_data_pd

# column_names = ["Temperature", "Latitude", "Longitude"]
# weather_data_pd = pd.DataFrame(data, index=cities, columns=column_names)
# weather_data_pd

# %%
# lat = []
# temp = []
# humidity=[]
# cloud=[]
# wind_speed=[]
# for city in cities:
#     response = requests.get(query_url + city).json()
#     #pprint(response)
#     print(city)
#     lat.append(response["coord"]["lat"])
#     temp.append(response["main"]["temp"])   
#     humidity.append(response["main"]["temp"]) 
#     cloud.append(response["weather"][0]["description"]) 
#     wind_speed.append(response["wind"]["speed"]) 

# print(lat, temp, humidity, cloud, wind_speed)

# %%
# weather_df = pd.DataFrame({
#     'City': cities,
#     'Latitude': lat,
#     'Temperature': temp,
#     'Humidity': humidity,
#     'Cloudiness': cloud,
#     'Wind Speed': wind_speed
# })
# weather_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_list_df[Lat], cities_list_df[Temp], marker='o')
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Images/TemperatureInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_list_df[Lat], cities_list_df[Humidity], marker='o')
plt.title("Humidity in World Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Images/HumidityInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_list_df[Lat], cities_list_df[Cloudiness], marker='o')
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Images/CloudinessInWorldCities.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_list_df[Lat], cities_list_df[Wind Speed], marker='o')
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Images/WindSpeedInWorldCities.png")
